# %%
class Atm:
  def __init__(Self):
    print('Hello')
    def menu(Self):
      pass

# %%
sbi=Atm()
# Out:
# Hello

# %%
# Almost everything in python is an object, with it's properties and methods.
# A class is like an object constructor, or a 'blueprint' for creating objects.

# %%
class Myclass:
  x=5

p1=Myclass()
print(p1.x)
# Out:
# 5

# %%
# create a class name person, use the __init__() function to assingn values for name and age.
class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age

p1 = Person('John',36)
print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %%
# object can also contain mathods . Methods in objects are functions that belongs to object.
class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age

  def myfunc(self):
    print('Hello my name is ',self.name,' Hello my age is ',self.age)

p1=Person('John',36)
p1.myfunc()
# Out:
# Hello my name is  John  Hello my age is  36

# %%
class Dimag:
  def __init__(self):
    self.pagal=" "
    self.menu()

  def menu(self):
    user_input = input("""
                           Hello Welcome to Pagalkhana
                           1. Enter 1 to pagal hai
                           2. Enter 2 to nhi hai
                           """)
    if user_input=="1":
      print('Pagal')
    elif user_input=="2":
      print('Avara')

# %%
GAurav=Dimag()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-94365363bd9b> in <cell line: 1>()
# ----> 1 GAurav=Dimag()
#
# NameError: name 'Dimag' is not defined

# %%
class Atm:
  def __init__(self):
    self.pin=" "
    self.balance=0
    self.menu()


  def menu(self):
    user_input = input("""
                           Hello Welcome to Bank
                           1. Enter 1 to create pin
                           2. Enter 2 to deposit
                           3. Enter 3 to withdrow
                           4. Enter 4 to check balance
                           5. Enter 5 to Exit
                            """)
    if user_input=="1":
      self.create_pin()
    elif user_input=="2":
      print('Withdrow')
    elif user_input=="3":
      print('deposit')
    elif user_input=="4":
      print('balance')
    else:
      print('Exit')

  def create_pin(self):
    self.pin=input('enter your pin')
    print('pin set successfully')

# %%
hdfc=Atm()
# Out:
#                            Hello Welcome to Bank
#                            1. Enter 1 to create pin
#                            2. Enter 2 to deposit
#                            3. Enter 3 to withdrow
#                            4. Enter 4 to check balance
#                            5. Enter 5 to Exit
#                             1
# enter your pin1234
# pin set successfully

# %%
class Atm:
  def __init__(self):
    self.pin=" "
    self.balance=0
    self.menu()


  def menu(self):
    user_input = input("""
                           Hello Welcome to 'RGPT' Bank how can i help you?
                           1. Enter 1 to create pin
                           2. Enter 2 to change pin
                           3. Enter 3 to check balance
                           4. Enter 4 to withdraw
                           5. Anything else to exit.
                            """)

    if user_input == "1":
      self.create_pin()
    elif user_input == "2":
      self.change_pin()
    elif user_input == "3":
      self.check_balance()
    elif user_input == "4":
      self.withdraw()
    else:
      print('Exit')

  def create_pin(self):
    user_pin = int(input('Enter your pin '))
    self.pin = user_pin

    user_balance = int(input('Enter balance '))
    self.balance = user_balance

    print('Pin created successfully ')
    self.menu()

  def change_pin(self):
    old_pin = int(input('Enter old pin '))

    if old_pin == self.pin:
      # let him change the pin
      new_pin = int(input('Enter new pin '))
      self.pin=new_pin
      print('Pin change successful ')
      self.menu()
    else:
      print('Not possible changing pin ')
      self.menu()
  def check_balance(self):
    user_pin=int(input('Enter your pin '))
    if user_pin == self.pin:
      print('your Balance is ', self.balance)
    else:
      print('No balance ')
    self.menu()

  def withdraw(self):
    user_pin=int(input('Enter your pin '))
    if user_pin == self.pin:
      #allow to withdraw
      amount=int(input('Enter your Amount '))
      if amount <= self.balance:
        self.balance=self.balance-amount
        print('''Withdraw Successful
                 your balance is''', self.balance)
      else:
        print('Withdraw Unsuccessful ')
    else:
      print(' wrong pin ')
    self.menu()

# %%
aaft=Atm()
# Out:
#                            Hello Welcome to 'RGPT' Bank how can i help you?
#                            1. Enter 1 to create pin
#                            2. Enter 2 to change pin
#                            3. Enter 3 to check balance
#                            4. Enter 4 to withdraw
#                            5. Anything else to exit.
#                             1
#  Enter your pin123
#  Enter balance3000
#  Pin created successfully
#
#                            Hello Welcome to 'RGPT' Bank how can i help you?
#                            1. Enter 1 to create pin
#                            2. Enter 2 to change pin
#                            3. Enter 3 to check balance
#                            4. Enter 4 to withdraw
#                            5. Anything else to exit.
#                             5
# Exit
